# %% [markdown]
# # Primer intento de SSL

# %% [markdown]
# ## Transformando el dataset
#
# El formato .npz guarda solamente arreglos de numpy, entonces para esto hay que extraerlo

# %%
data_flag = '../compartido/datasets/'
download = True

NUM_EPOCHS = 3
BATCH_SIZE = 128
lr = 0.001

info = INFO[data_flag]
task = info['task']
n_channels = info['n_channels']
n_classes = len(info['label'])

DataClass = getattr(medmnist, info['python_class'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 BATCH_SIZE = 128
#       6 lr = 0.001
# ----> 8 info = INFO[data_flag]
#       9 task = info['task']
#      10 n_channels = info['n_channels']
#
# NameError: name 'INFO' is not defined
